# %%
# !pip install keras

# %%
# !pip install tensorflow matplotlib opencv-python sklearn matplotlib
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f4/f0/564e62d191f0f98f5a2c7c25c472fb19c5b418b174608e6727c7f1878826/tensorflow-2.8.2-cp37-cp37m-manylinux2010_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/df/e7/0ad4aad00d6d0314aaf97526a54a34d385f898ebb7915d112431fff452ff/matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/3c/61/ee4496192ed27f657532fdf0d814b05b9787e7fc5122ed3ca57282bae69c/opencv-python-4.5.5.64.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached https://files.pythonhosted.org/packages/3d/d0/26033c70d642fbc1e35d3619cf3210986fb953c173b1226709f75056c149/flatbuffers-2.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl
# ...

# %%
# !pip install pillow
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/43/6e/59853546226ee6200f9ba6e574d11604b60ad0754d2cbd1c8f3246b70418/Pillow-9.1.1.tar.gz
# ...
#   ERROR: Complete output from command /snap/jupyter/6/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/tmp/pip-install-e5rj9erp/pillow/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-6726mg1o --python-tag cp37:
#   ERROR: running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/PIL
#   copying src/PIL/GribStubImagePlugin.py -> build/lib.linux-x86_64-3.7/PIL
#   copying src/PIL/ImageStat.py -> build/lib.linux-x86_64-3.7/PIL
#   copying src/PIL/TgaImagePlugin.py -> build/lib.linux-x86_64-3.7/PIL
#   copying src/PIL/ImImagePlugin.py -> build/lib.linux-x86_64-3.7/PIL
# ...

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-58c1cdc3c7cc> in <module>
# ----> 1 import tensorflow
#       2 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'tensorflow'
